# %% [markdown]
# # Ollama Embeddings

# %%
# from langchain_community.embeddings import OllamaEmbeddings
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(model='mxbai-embed-large')
embeddings
# Out:
# OllamaEmbeddings(model='mxbai-embed-large', base_url=None, client_kwargs={}, async_client_kwargs={}, sync_client_kwargs={}, mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, keep_alive=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None)

# %%
embed_doc = embeddings.embed_documents(
    'which is the test document?'
)
embed_doc
# Out:
# [[0.014529741,
#   -0.022903541,
#   0.053447343,
#   0.03295565,
#   -0.047624096,
#   -0.0042130705,
#   0.00052719016,
#   -0.0065579223,
#   0.02019265,
#   0.067405604,
#   0.014319208,
#   0.045211706,
#   0.024369987,
#   0.0015327939,
#   -0.012213514,
#   0.009247213,
#   -0.018101096,
#   0.029619133,
#   -0.029274903,
#   -0.044996705,
#   -0.05378888,
#   0.022015225,
#   -0.055809364,
#   -0.0068240394,
#   -0.01683845,
#   0.010785275,
#   -0.036611244,
#   0.0030226554,
#   0.04732572,
#   0.010355712,
#   -0.023697292,
#   0.01778813,
#   -0.04400668,
#   -0.034086704,
#   0.017229106,
#   -0.047317408,
#   0.06023498,
#   -0.033992324,
#   0.0026677365,
#   -0.040667877,
#   -0.013578144,
#   0.01528836,
#   0.033126354,
#   -0.035450973,
#   -0.079242535,
#   -0.032182425,
#   -0.0173026,
#   -0.014655068,
#   -0.052919418,
#   -0.03444563,
#   0.023328241,
#   0.03303461,
#   -0.023777429,
#   -0.0444863,
#   0.005336143,
#   -0.023029616,
#   -0.030250601,
# ...

# %%
text = 'This is a test document.'
query_result = embeddings.embed_query(text)
query_result
# Out:
# [0.007114112,
#  -0.018595371,
#  0.05574884,
#  0.02430542,
#  -0.051251117,
#  -0.0021903266,
#  -0.0024498496,
#  -0.008702137,
#  0.02206758,
#  0.05521415,
#  0.013424975,
#  0.026505152,
#  0.02683053,
#  0.007171761,
#  -0.020775383,
#  0.012972035,
#  -0.022506582,
#  0.031163612,
#  -0.030888703,
#  -0.028512327,
#  -0.04215452,
#  0.014364429,
#  -0.053491235,
#  -0.019486092,
#  -0.0251048,
#  0.035284176,
#  -0.012704372,
#  0.0042947335,
#  0.06716234,
#  0.018896295,
#  -0.0041273,
#  0.015777893,
#  -0.035957303,
#  -0.04714481,
#  0.02043739,
#  -0.043359123,
#  0.062308233,
#  -0.03513025,
#  0.0022427319,
#  -0.03195952,
#  0.004532007,
#  0.009770302,
#  0.042880837,
#  -0.03426364,
#  -0.08437963,
#  -0.04422735,
#  -0.0147990445,
#  -0.008102188,
#  -0.027713282,
#  -0.027542736,
#  0.014829927,
#  0.030832065,
#  -0.010884567,
#  -0.035570886,
#  0.00060935586,
#  -0.020554807,
#  -0.024288565,
#  -0.024684971,
#  -0.03625391,
#  0.06537428,
#  0.052429654,
# ...

# %%
len(query_result)
# Out:
# 1024

# %%
embed_doc = embeddings.embed_documents(
    [
        'Alpha is the first letter of Greek alphabet',
        'Beta is the second letter of Greek alphabet',
    ]
)
embed_doc[1]
# Out:
# [0.0087651,
#  0.0004637393,
#  0.050938558,
#  -0.026229369,
#  -0.08244179,
#  0.004886882,
#  0.06573993,
#  0.038346004,
#  -0.030609872,
#  0.0152986655,
#  0.014392799,
#  -0.010580737,
#  -0.01679764,
#  0.025527123,
#  -0.041944686,
#  -0.001613442,
#  -0.034525298,
#  -0.037016425,
#  -0.044349298,
#  -0.026569467,
#  0.046366364,
#  0.040203076,
#  -0.05911252,
#  0.0022103179,
#  -0.007817557,
#  0.045705706,
#  -0.009288127,
#  -0.015466312,
#  0.054138653,
#  0.055481523,
#  -0.0024717648,
#  0.014124146,
#  0.04678171,
#  -0.057238232,
#  -0.015744833,
#  -0.0090795485,
#  0.035208926,
#  -0.007431796,
#  -0.017723788,
#  -0.046267565,
#  0.055935703,
#  -0.020169547,
#  0.004406018,
#  -0.017667934,
#  -0.05969492,
#  0.0056679365,
#  -0.0046001947,
#  -0.06191961,
#  -0.05325334,
#  -0.024736332,
#  -0.010995873,
#  0.0012381471,
#  0.027504254,
#  -0.043040417,
#  -0.056641877,
#  0.004452415,
#  0.028000593,
#  -0.012489004,
#  -0.02631151,
#  0.02259679,
# ...

# %%
prompt = 'the second letter of Greek alphabet?'

result_query = embeddings.embed_query(prompt)
result_query
# Out:
# [0.004555666,
#  0.011520652,
#  0.029960029,
#  -0.020917526,
#  -0.08026043,
#  -0.02274821,
#  0.074573286,
#  0.01699424,
#  -0.0010870617,
#  0.032016665,
#  0.012967093,
#  0.009464476,
#  -0.031665005,
#  0.012870547,
#  -0.05498812,
#  -0.007814194,
#  0.0009464552,
#  -0.019125003,
#  -0.054689623,
#  -0.0059426045,
#  0.06477503,
#  0.03686698,
#  -0.067035645,
#  0.017877564,
#  0.004401711,
#  0.022133024,
#  -0.0173979,
#  -0.028847761,
#  -0.008224742,
#  0.048946243,
#  -0.020611342,
#  0.018544998,
#  0.018626202,
#  -0.05990943,
#  0.0044775424,
#  -0.03718604,
#  0.036340553,
#  -0.032466043,
#  -0.010050002,
#  -0.06326814,
#  0.0356938,
#  -0.010160896,
#  -0.014340922,
#  -0.015623934,
#  -0.026241204,
#  -0.014121851,
#  -0.012652029,
#  -0.039654557,
#  -0.07380804,
#  -0.013379722,
#  3.6243833e-05,
#  -0.0125395795,
#  0.04999168,
#  -0.0376837,
#  -0.049587257,
#  0.019710785,
#  0.04616953,
#  -0.0019427422,
#  -0.018152062,
#  0.022620399,
#  0.026822587,
# ...

# %% [markdown]
# # hugging face embeddings

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
hf_token = os.getenv('HF_TOKEN')

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name='all-Mini-L6-v2')
embeddings
